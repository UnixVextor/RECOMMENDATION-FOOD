# %% [markdown]
# # อาหารวันนี้ฉันขอเลือกนาย
# [Nutritive Value Of Thai Foods](https://nutrition2.anamai.moph.go.th/th/thai-food-composition-table/download?id=61523&mid=31993&mkey=m_document&lang=th&did=18032) ข้อมูลคุณค่าทางโภชนาการของอาหารจานเดียว
#
# ### 🗂️ Data ประกอบด้วยดังนี้ :
#
# - `Energy(kcal)` : พลังงานของอาหาร
# - `Water(g)` : ปริมาณนํ้าในร่างกาย
# - `Protein(g)` :ปริมาณโปรตีน
# - `Fat(g)` : ปริมาณไขมัน
# - `Carbohydrate, available\n(carbohydrate, total)(g)` : ปริมาณคาร์โบไฮเดรต
# - `Dietary fibre(g)` : ปริมาณเส้นใยอาหาร
# - `Ash(g)` : ปริมาณเศษเถ้า
# - `Calcium(mg)` : ปริาณแคลเซียม
# - `Phosphorus(mg)` : ปริมาณฟอสฟอรัส
# - `Magnesium(mg)` : ปริมาณแมกนีเซียม
# - `Sodium(mg)` : ปริมาณโซเดียม
# - `Potassium(mg)` : ปริมาณโพแทสเซียม
# - `Iron(mg)` : ปริมาณแร่ธาตุเหล็ก
# - `Copper(mg)` : ปริมาณแร่ธาตุทองแดง
# - `Zinc(mg)` : ปริมาณแร่ธาตุสังกะสี
# - `Iodine(ug)` : ปริมาณไอโอดีน
# - `Betacarotene(ug)` : ปริมาณเบต้าแคโรทีน
# - `Retinol(ug)` : ปริมาณสารที่พบใน Vitamin A
# - `Total Vitamin A (RAE)(ug)` : ปริมาณ Vitamin A ทั้งหมดที่พบในอาหาร
# - `Thiamine(mg)` : ปริมาณ Vitamin B1
# - `Riboflavin(mg)` : ปริมาณ Vitamin B2
# - `Niacin(mg)` : ปริมาณ Vitamin B3
# - `Vitamin C(mg)` : ปริมาณ Vitamin C
# - `Vitamin E(mg)` : ปริมาณ Vitamin E

# %% [markdown]
# ### 📒 นำเข้า Library ที่จำเป็น

# %%
# import neccesary library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 🗄️ นำเข้า Data Set

# %%
# read data from excel
df = pd.read_excel('Nutritive-Value-Of-Thai-Foods-3 - Fix.xlsx')
df
# Out:
#      Food ID     Food and Description Thai  \
# 0      11001                    กระเพาะปลา
# 1      11002          กระเพาะปลา, เส้นหมี่
# 2      11003                ก๋วยจั๋บน้ำข้น
# 3      11004  ก๋วยเตี๋ยวแขก(ก๋วยเตี๋ยวแกง)
# 4      11005             ก๋วยเตี๋ยวคั่วไก่
# ..       ...                           ...
# 229    11230           หมี่กึงรวม, อาหารเจ
# 230    11231  หมี่เหลืองผัดซีอิ้ว, อาหารเจ
# 231    11232             หมู - ไต, อาหารเจ
# 232    11233              หมูย่าง, อาหารเจ
# 233    11234           หมูสามชั้น, อาหารเจ
#
#                           Food and Description English  Energy(kcal)  \
# 0                                       Fish maw soup             83
# 1     Fish maw soup with rice noodles \n(fine thread)             60
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 3                        Rice noodles with beef curry            131
# 4                    Rice noodles with chicken, fried            198
# ..                                                 ...           ...
# 229                     Vegetarian, kueng rice noodles           134
# 230     Vegetarian, friend yellow noodles in soy sause           131
# 231                        Vegetarian, pork-pig kidney            36
# 232                           Vegetarian, roasted pork           231
# 233                           Vegetarian, streaky pork            98
#
#      Water(g)  Protein(g)  Fat(g)  \
# 0        85.0        7.30    5.20
# 1        84.7        3.75    0.75
# 2        84.3       39.10    1.88
# 3        75.0        6.60    7.40
# 4        59.7        6.94    8.36
# ..        ...         ...     ...
# 229      67.4       26.79    0.90
# 230      72.9        3.20    5.40
# 231      88.8        0.71    0.60
# 232      54.8       19.90   12.20
# 233      77.7        2.01    3.41
#
#      Carbohydrate, available\n(carbohydrate, total)(g) Dietary fibre(g)  \
# 0                                                 1.80                -
# 1                                                 9.46                -
# 2                                                 8.49                -
# 3                                                 9.40              0.3
# 4                                                23.77                -
# ..                                                 ...              ...
# 229                                               4.70                -
# 230                                              17.30              0.5
# 231                                               6.97                -
# 232                                              10.32                -
# 233                                              14.92                -
#
#     Ash(g)  ... Zinc(mg) Iodine(ug) Betacarotene(ug) Retinol(ug)  \
# 0      0.7  ...        -          -               14         164
# 1     1.37  ...        -          -                -           -
# 2     1.38  ...        -          -                -           -
# 3      1.6  ...        -          -               22           0
# 4     1.21  ...        -          -                -           -
# ..     ...  ...      ...        ...              ...         ...
# 229   0.33  ...        -          4                -           -
# 230    1.2  ...        -          -              168           -
# 231   2.97  ...        -          -                -           -
# 232   2.74  ...        -         49                -           -
# 233   1.97  ...        -         34                -           -
#
#     Total Vitamin A (RAE)(ug) Thiamine(mg) Riboflavin(mg) Niacin(mg)  \
# 0                         165         0.01           0.32        1.6
# 1                           -            -              -          -
# 2                           -            -              -          -
# 3                           2         0.12           0.86        1.6
# 4                           -            -              -          -
# ..                        ...          ...            ...        ...
# 229                         -            -           0.06          -
# 230                        14         0.71            2.6          -
# 231                         -            -              -          -
# 232                         -         0.02           0.12          -
# 233                         -            0           0.07          -
#
#     Vitamin C(mg) Vitamin E(mg)
# 0               0             -
# 1               -             -
# 2               -             -
# 3               -             -
# 4               -             -
# ..            ...           ...
# 229             -             -
# 230             -             -
# 231             -             -
# 232             -             -
# 233             -             -
#
# [234 rows x 27 columns]

# %% [markdown]
# ### 💾 กรองข้อมูลที่จำเป็นต้องใช้
# **โดยข้อมูลมีดังต่อไปนี้**
# - `Energy(kcal)` : พลังงานของอาหาร
# - `Water(g)` : ปริมาณนํ้าในร่างกาย
# - `Protein(g)` :ปริมาณโปรตีน
# - `Fat(g)` : ปริมาณไขมัน
# - `Carbohydrate, available\n(carbohydrate, total)(g)` : ปริมาณคาร์โบไฮเดรต

# %%
Filter_df = df.filter(items = ['Food and Description Thai','Food and Description English','Energy(kcal)','Protein(g)','Fat(g)','Carbohydrate, available\n(carbohydrate, total)(g)'])
Filter_df
# Out:
#         Food and Description Thai  \
# 0                      กระเพาะปลา
# 1            กระเพาะปลา, เส้นหมี่
# 2                  ก๋วยจั๋บน้ำข้น
# 3    ก๋วยเตี๋ยวแขก(ก๋วยเตี๋ยวแกง)
# 4               ก๋วยเตี๋ยวคั่วไก่
# ..                            ...
# 229           หมี่กึงรวม, อาหารเจ
# 230  หมี่เหลืองผัดซีอิ้ว, อาหารเจ
# 231             หมู - ไต, อาหารเจ
# 232              หมูย่าง, อาหารเจ
# 233           หมูสามชั้น, อาหารเจ
#
#                           Food and Description English  Energy(kcal)  \
# 0                                       Fish maw soup             83
# 1     Fish maw soup with rice noodles \n(fine thread)             60
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 3                        Rice noodles with beef curry            131
# 4                    Rice noodles with chicken, fried            198
# ..                                                 ...           ...
# 229                     Vegetarian, kueng rice noodles           134
# 230     Vegetarian, friend yellow noodles in soy sause           131
# 231                        Vegetarian, pork-pig kidney            36
# 232                           Vegetarian, roasted pork           231
# 233                           Vegetarian, streaky pork            98
#
#      Protein(g)  Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)
# 0          7.30    5.20                                               1.80
# 1          3.75    0.75                                               9.46
# 2         39.10    1.88                                               8.49
# 3          6.60    7.40                                               9.40
# 4          6.94    8.36                                              23.77
# ..          ...     ...                                                ...
# 229       26.79    0.90                                               4.70
# 230        3.20    5.40                                              17.30
# 231        0.71    0.60                                               6.97
# 232       19.90   12.20                                              10.32
# 233        2.01    3.41                                              14.92
#
# [234 rows x 6 columns]

# %% [markdown]
# ## Cosine Similarity
# **Cosine similarity** หรือ ความคล้ายคลึงโคไซน์ ค่าจะขึ้นอยู่กับมุมที่เวกเตอร์ 2 เวกเตอร์กระทำต่อกัน
# ![Cosine Similarity](image/cosine_similarity.png)
#
# โดยที่ Cosine Similarity จะมีสูตรคำนวณดังนี้
# ### $$D_{Cosine} = cos\theta = \dfrac{u\cdot v}{|u||v|}$$
#
# - $u$ : ข้อมูลชุดที่ 1
# - $v$ : ข้อมูลชุดที่ 2
#
#
# จากสมการนำมาเขียนเป็นอยู่ในรูปผลรวมได้คือ
# ### $$D_{Cosine} = \dfrac{\sum_{i=1}^{n} A_i B_i}{\sqrt{\sum_{i=1}^{n} A_i^2} \sqrt{\sum_{i=1}^{n} B_i^2}}$$

# %%
import math
def cosinSimilarity(lstInput):
    for i in range(233):
        data = np.array([Filter_df['Energy(kcal)'][i],Filter_df['Protein(g)'][i],Filter_df['Fat(g)'][i],Filter_df['Carbohydrate, available\n(carbohydrate, total)(g)'][i]],dtype=float)
        dot = np.dot(lstInput,data)
        magData = np.linalg.norm(data)
        magLstInput = np.linalg.norm(lstInput)
        cosine = dot/(magData*magLstInput)
        degree = float("{0:.3f}".format((math.acos(cosine) * 180/math.pi)))
        
#         print("Cosine =","{0:.6f}".format(cosine),end=' ') 
#         print("Degree =",degree,'°')
        Filter_df.loc[i,'Cosine Similarity'] = "{0:.6f}".format(cosine)
        Filter_df.loc[i,'Degree Cosine Similarity'] = degree

# %% [markdown]
# ### ⌨️ รับข้อมูลจากผู้ใช้

# %%
energy = float(input("Enter Energy(kcal) : "))
protein = float(input("Enter Protein(g) : "))
fat  = float(input("Enter Fat(g) : "))
carbohydrate = float(input("Enter Carbohydrate(g) : "))
lstInput = np.array([energy,protein,fat,carbohydrate])
# printDetail(energy,protein,fat,carbohydrate)
cosinSimilarity(lstInput)
Filter_df
# Out:
# Enter Energy(kcal) : 98
# Enter Protein(g) : 2
# Enter Fat(g) : 12.20
# Enter Carbohydrate(g) : 8.49
#         Food and Description Thai  \
# 0                      กระเพาะปลา
# 1            กระเพาะปลา, เส้นหมี่
# 2                  ก๋วยจั๋บน้ำข้น
# 3    ก๋วยเตี๋ยวแขก(ก๋วยเตี๋ยวแกง)
# 4               ก๋วยเตี๋ยวคั่วไก่
# ..                            ...
# 229           หมี่กึงรวม, อาหารเจ
# 230  หมี่เหลืองผัดซีอิ้ว, อาหารเจ
# 231             หมู - ไต, อาหารเจ
# 232              หมูย่าง, อาหารเจ
# 233           หมูสามชั้น, อาหารเจ
#
#                           Food and Description English  Energy(kcal)  \
# 0                                       Fish maw soup             83
# 1     Fish maw soup with rice noodles \n(fine thread)             60
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 3                        Rice noodles with beef curry            131
# 4                    Rice noodles with chicken, fried            198
# ..                                                 ...           ...
# 229                     Vegetarian, kueng rice noodles           134
# 230     Vegetarian, friend yellow noodles in soy sause           131
# 231                        Vegetarian, pork-pig kidney            36
# 232                           Vegetarian, roasted pork           231
# 233                           Vegetarian, streaky pork            98
#
#      Protein(g)  Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)  \
# 0          7.30    5.20                                               1.80
# 1          3.75    0.75                                               9.46
# 2         39.10    1.88                                               8.49
# 3          6.60    7.40                                               9.40
# 4          6.94    8.36                                              23.77
# ..          ...     ...                                                ...
# 229       26.79    0.90                                               4.70
# 230        3.20    5.40                                              17.30
# 231        0.71    0.60                                               6.97
# 232       19.90   12.20                                              10.32
# 233        2.01    3.41                                              14.92
#
#     Cosine Similarity  Degree Cosine Similarity
# 0            0.993823                     6.371
# 1            0.990571                     7.874
# 2            0.870815                    29.447
# 3            0.997195                     4.292
# 4            0.996036                     5.103
# ..                ...                       ...
# 229          0.976422                    12.467
# 230          0.995590                     5.383
# 231          0.988834                     8.570
# 232          0.994504                     6.010
# 233               NaN                       NaN
#
# [234 rows x 8 columns]

# %% [markdown]
# ### 〽️ Sort ข้อมูลโดยเรียงลำดับจากมากไปน้อย

# %%
Filter_df.sort_values(['Cosine Similarity'],ascending=0,inplace = True)
Filter_df
# Out:
#                     Food and Description Thai  \
# 180                         ขนมจีน, น้ำเงี้ยว
# 96                                     หอยทอด
# 57                      ข้าวราดไข่เจียวหมูสับ
# 212                       ต้มจับฉ่าย, อาหารเจ
# 206                                 กาน่าฉ่าย
# ..                                        ...
# 115  ปลาทูน่า, เนื้อขาว, ชนิดก้อน, ในน้ำเกลือ
# 117                      ปลาทูน่า, ในน้ำเกลือ
# 116    ปลาทูน่า, เนื้อขาว, ชนิดก้อน, ในน้ำแร่
# 2                              ก๋วยจั๋บน้ำข้น
# 233                       หมูสามชั้น, อาหารเจ
#
#                           Food and Description English  Energy(kcal)  \
# 180  Round rice noodles with minced pork, spare rip...           107
# 96   Green mussel fried with flour, egg and and mun...           292
# 57                 Rice topped with minced pork omelet           236
# 212                 Vegetarian, chinese vegetable stew            50
# 206          Vegetarian, check of mustard (Ghana chai)           249
# ..                                                 ...           ...
# 115                        White tuna, canned in brine           112
# 117                              Tuna, canned in brine           129
# 116                        White tuna, canned in water           115
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 233                           Vegetarian, streaky pork            98
#
#      Protein(g)  Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)  \
# 180        2.71    8.42                                               5.20
# 96         8.86   21.36                                              16.13
# 57         8.15   15.56                                              15.93
# 212        1.85    3.40                                               3.12
# 206        1.69   23.74                                               7.15
# ..          ...     ...                                                ...
# 115       26.40    0.66                                               0.00
# 117       30.71    0.67                                               0.00
# 116       27.93    0.40                                               0.00
# 2         39.10    1.88                                               8.49
# 233        2.01    3.41                                              14.92
#
#     Cosine Similarity  Degree Cosine Similarity
# 180          0.998269                     3.372
# 96           0.998194                     3.444
# 57           0.998057                     3.572
# 212          0.998029                     3.598
# 206          0.997863                     3.746
# ..                ...                       ...
# 115          0.967443                    14.660
# 117          0.966900                    14.783
# 116          0.965740                    15.041
# 2            0.870815                    29.447
# 233               NaN                       NaN
#
# [234 rows x 8 columns]

# %% [markdown]
# ### List ข้อมูลอาหาร 10 อันดับแรก

# %%
Sort_df = Filter_df[['Food and Description Thai','Energy(kcal)','Protein(g)','Fat(g)','Carbohydrate, available\n(carbohydrate, total)(g)']]
Sort_df.head(10)
# Out:
#           Food and Description Thai  Energy(kcal)  Protein(g)  Fat(g)  \
# 180               ขนมจีน, น้ำเงี้ยว           107        2.71    8.42
# 96                           หอยทอด           292        8.86   21.36
# 57            ข้าวราดไข่เจียวหมูสับ           236        8.15   15.56
# 212             ต้มจับฉ่าย, อาหารเจ            50        1.85    3.40
# 206                       กาน่าฉ่าย           249        1.69   23.74
# 38             ขนมผักกาดผัด, ใส่ไข่           196        4.30   11.50
# 142                     ขนมจีนน้ำยา            95        2.40    5.40
# 221  ผัดวุ้นเส้น (ผัดโฮ๊ะ), อาหารเจ           152        1.40    9.10
# 181                    ข้าวซอย, ไก่           151        5.83   10.56
# 228               หมี่กรอบ, อาหารเจ           182        2.70   10.20
#
#      Carbohydrate, available\n(carbohydrate, total)(g)
# 180                                               5.20
# 96                                               16.13
# 57                                               15.93
# 212                                               3.12
# 206                                               7.15
# 38                                               18.90
# 142                                               9.07
# 221                                              16.10
# 181                                               7.37
# 228                                              19.90

# %% [markdown]
# ### Correlation Matrix
#   Correlation หรือ สหสัมพันธ์คือการศึกษาหาความสัมพันธ์ระหว่างตัวแปร 2 ตัวแปรขึ้นไปสามารถเขียนในรูปสมการคือ
#    ### $$r_{xy} = \dfrac{\sum (x_i-\bar x)(y_i-\bar y)}{\sqrt{\sum (x_i-\bar x)^2 \sum (y_i-\bar y)^2}}$$
#
# - $x$ : ข้อมูลชุดที่ 1
# - $y$ : ข้อมูลชุดที่ 2
# - $\bar x $ : ค่าเฉลี่ยของข้อมูลชุดที่ 1
#   $$ \bar x = \dfrac{\sum_{i=1}^{n} x_i}{n}$$
# - $\bar y $ : ค่าเฉลี่ยของข้อมูลชุดที่ 2
#   $$ \bar y = \dfrac{\sum_{i=1}^{n} y_i}{n}$$

# %%
cor = Sort_df.iloc[:10,1:].transpose().corr()
cor
# Out:
#           180       96        57        212       206       38        142  \
# 180  1.000000  0.999936  0.999612  0.999730  0.999390  0.998131  0.998157
# 96   0.999936  1.000000  0.999858  0.999929  0.998933  0.998601  0.998655
# 57   0.999612  0.999858  1.000000  0.999973  0.998066  0.999232  0.999307
# 212  0.999730  0.999929  0.999973  1.000000  0.998310  0.998917  0.999006
# 206  0.999390  0.998933  0.998066  0.998310  1.000000  0.996003  0.995928
# 38   0.998131  0.998601  0.999232  0.998917  0.996003  1.000000  0.999989
# 142  0.998157  0.998655  0.999307  0.999006  0.995928  0.999989  1.000000
# 221  0.997212  0.997678  0.998400  0.997970  0.995159  0.999813  0.999723
# 181  0.999820  0.999911  0.999743  0.999883  0.998689  0.998093  0.998207
# 228  0.996961  0.997517  0.998355  0.997908  0.994619  0.999834  0.999775
#
#           221       181       228
# 180  0.997212  0.999820  0.996961
# 96   0.997678  0.999911  0.997517
# 57   0.998400  0.999743  0.998355
# 212  0.997970  0.999883  0.997908
# 206  0.995159  0.998689  0.994619
# 38   0.999813  0.998093  0.999834
# 142  0.999723  0.998207  0.999775
# 221  1.000000  0.996916  0.999964
# 181  0.996916  1.000000  0.996813
# 228  0.999964  0.996813  1.000000

# %%
fig,ax = plt.subplots(figsize=(20,20))
sns.heatmap(data = cor, cmap='Greens',annot=True,
           annot_kws = {
               'fontsize' : 16,
               'fontweight' : 'bold'
           },fmt='.5g')
Sort_df.head(10)
# Out:
#           Food and Description Thai  Energy(kcal)  Protein(g)  Fat(g)  \
# 180               ขนมจีน, น้ำเงี้ยว           107        2.71    8.42
# 96                           หอยทอด           292        8.86   21.36
# 57            ข้าวราดไข่เจียวหมูสับ           236        8.15   15.56
# 212             ต้มจับฉ่าย, อาหารเจ            50        1.85    3.40
# 206                       กาน่าฉ่าย           249        1.69   23.74
# 38             ขนมผักกาดผัด, ใส่ไข่           196        4.30   11.50
# 142                     ขนมจีนน้ำยา            95        2.40    5.40
# 221  ผัดวุ้นเส้น (ผัดโฮ๊ะ), อาหารเจ           152        1.40    9.10
# 181                    ข้าวซอย, ไก่           151        5.83   10.56
# 228               หมี่กรอบ, อาหารเจ           182        2.70   10.20
#
#      Carbohydrate, available\n(carbohydrate, total)(g)
# 180                                               5.20
# 96                                               16.13
# 57                                               15.93
# 212                                               3.12
# 206                                               7.15
# 38                                               18.90
# 142                                               9.07
# 221                                              16.10
# 181                                               7.37
# 228                                              19.90
