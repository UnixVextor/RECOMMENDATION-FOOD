# %% [markdown]
# # อาหารวันนี้ฉันขอเลือกนาย
# [Nutritive Value Of Thai Foods](https://nutrition2.anamai.moph.go.th/th/thai-food-composition-table/download?id=61523&mid=31993&mkey=m_document&lang=th&did=18032) ข้อมูลคุณค่าทางโภชนาการของอาหารจานเดียว
#
# ### 🗂️ Data ประกอบด้วยดังนี้ :
#
# - `Energy(kcal)` : พลังงานของอาหาร
# - `Water(g)` : ปริมาณนํ้าในร่างกาย
# - `Protein(g)` :ปริมาณโปรตีน
# - `Fat(g)` : ปริมาณไขมัน
# - `Carbohydrate, available\n(carbohydrate, total)(g)` : ปริมาณคาร์โบไฮเดรต
# - `Dietary fibre(g)` : ปริมาณเส้นใยอาหาร
# - `Ash(g)` : ปริมาณเศษเถ้า
# - `Calcium(mg)` : ปริาณแคลเซียม
# - `Phosphorus(mg)` : ปริมาณฟอสฟอรัส
# - `Magnesium(mg)` : ปริมาณแมกนีเซียม
# - `Sodium(mg)` : ปริมาณโซเดียม
# - `Potassium(mg)` : ปริมาณโพแทสเซียม
# - `Iron(mg)` : ปริมาณแร่ธาตุเหล็ก
# - `Copper(mg)` : ปริมาณแร่ธาตุทองแดง
# - `Zinc(mg)` : ปริมาณแร่ธาตุสังกะสี
# - `Iodine(ug)` : ปริมาณไอโอดีน
# - `Betacarotene(ug)` : ปริมาณเบต้าแคโรทีน
# - `Retinol(ug)` : ปริมาณสารที่พบใน Vitamin A
# - `Total Vitamin A (RAE)(ug)` : ปริมาณ Vitamin A ทั้งหมดที่พบในอาหาร
# - `Thiamine(mg)` : ปริมาณ Vitamin B1
# - `Riboflavin(mg)` : ปริมาณ Vitamin B2
# - `Niacin(mg)` : ปริมาณ Vitamin B3
# - `Vitamin C(mg)` : ปริมาณ Vitamin C
# - `Vitamin E(mg)` : ปริมาณ Vitamin E

# %% [markdown]
# ### 📒 นำเข้า Library ที่จำเป็น

# %%
# import neccesary library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 🗄️ นำเข้า Data Set

# %%
# read data from excel
df = pd.read_excel('Nutritive-Value-Of-Thai-Foods-3 - Fix.xlsx')
df
# Out:
#      Food ID     Food and Description Thai  \
# 0      11001                    กระเพาะปลา
# 1      11002          กระเพาะปลา, เส้นหมี่
# 2      11003                ก๋วยจั๋บน้ำข้น
# 3      11004  ก๋วยเตี๋ยวแขก(ก๋วยเตี๋ยวแกง)
# 4      11005             ก๋วยเตี๋ยวคั่วไก่
# ..       ...                           ...
# 153    11154         แกงน้ำเคย (แกงเคยปลา)
# 154    11155             แกงพริกปลาตัวเล็ก
# 155    11156               แกงมัสมั่นเนื้อ
# 156    11157            แกงส้มผักรวมกับปลา
# 157    11158               แกงเหลืองใส่ปลา
#
#                           Food and Description English  Energy(kcal)  \
# 0                                       Fish maw soup             83
# 1     Fish maw soup with rice noodles \n(fine thread)             60
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 3                        Rice noodles with beef curry            131
# 4                    Rice noodles with chicken, fried            198
# ..                                                 ...           ...
# 153                         Curry, fermented tiny fish            39
# 154                                  Curry, small fish            74
# 155                              Curry, matsaman, beef           252
# 156                      Kang-som, vegetables and fish            50
# 157                     Yellow curry (sour soup), fish            41
#
#      Water(g)  Protein(g)  Fat(g)  \
# 0        85.0        7.30    5.20
# 1        84.7        3.75    0.75
# 2        84.3       39.10    1.88
# 3        75.0        6.60    7.40
# 4        59.7        6.94    8.36
# ..        ...         ...     ...
# 153      86.8        6.97    0.69
# 154      80.5        9.96    2.43
# 155      66.0       10.21   23.42
# 156      87.4        5.22    2.98
# 157      85.5        7.80    0.14
#
#      Carbohydrate, available\n(carbohydrate, total)(g) Dietary fibre(g)  \
# 0                                                 1.80                -
# 1                                                 9.46                -
# 2                                                 8.49                -
# 3                                                 9.40              0.3
# 4                                                23.77                -
# ..                                                 ...              ...
# 153                                               1.15                -
# 154                                               3.03                -
# 155                                               0.00                -
# 156                                               0.56                -
# 157                                               1.32              1.6
#
#      Ash(g)  ... Zinc(mg) Iodine(ug) Betacarotene(ug) Retinol(ug)  \
# 0      0.70  ...        -          -               14         164
# 1      1.37  ...        -          -                -           -
# 2      1.38  ...        -          -                -           -
# 3      1.60  ...        -          -               22           0
# 4      1.21  ...        -          -                -           -
# ..      ...  ...      ...        ...              ...         ...
# 153    4.40  ...        -         38               38           0
# 154    4.10  ...        -         36               41           0
# 155    2.36  ...     3.28         40               60          60
# 156    3.80  ...        -         36                0           0
# 157    3.69  ...     1.98         87               55           0
#
#     Total Vitamin A (RAE)(ug) Thiamine(mg) Riboflavin(mg) Niacin(mg)  \
# 0                         165         0.01           0.32        1.6
# 1                           -            -              -          -
# 2                           -            -              -          -
# 3                           2         0.12           0.86        1.6
# 4                           -            -              -          -
# ..                        ...          ...            ...        ...
# 153                         3            -           0.07       2.12
# 154                         3            -            0.1       1.83
# 155                        65         0.05            0.2       2.49
# 156                         0         0.05           0.07       1.76
# 157                         5         0.06           0.04       1.85
#
#     Vitamin C(mg) Vitamin E(mg)
# 0               0             -
# 1               -             -
# 2               -             -
# 3               -             -
# 4               -             -
# ..            ...           ...
# 153             -          0.04
# 154             -          0.74
# 155             -          0.54
# 156             -          0.34
# 157             -          0.38
#
# [158 rows x 27 columns]

# %% [markdown]
# ### 💾 กรองข้อมูลที่จำเป็นต้องใช้
# **โดยข้อมูลมีดังต่อไปนี้**
# - `Energy(kcal)` : พลังงานของอาหาร
# - `Water(g)` : ปริมาณนํ้าในร่างกาย
# - `Protein(g)` :ปริมาณโปรตีน
# - `Fat(g)` : ปริมาณไขมัน
# - `Carbohydrate, available\n(carbohydrate, total)(g)` : ปริมาณคาร์โบไฮเดรต

# %%
Filter_df = df.filter(items = ['Food and Description Thai','Food and Description English','Energy(kcal)','Protein(g)','Fat(g)','Carbohydrate, available\n(carbohydrate, total)(g)'])
Filter_df
# Out:
#         Food and Description Thai  \
# 0                      กระเพาะปลา
# 1            กระเพาะปลา, เส้นหมี่
# 2                  ก๋วยจั๋บน้ำข้น
# 3    ก๋วยเตี๋ยวแขก(ก๋วยเตี๋ยวแกง)
# 4               ก๋วยเตี๋ยวคั่วไก่
# ..                            ...
# 153         แกงน้ำเคย (แกงเคยปลา)
# 154             แกงพริกปลาตัวเล็ก
# 155               แกงมัสมั่นเนื้อ
# 156            แกงส้มผักรวมกับปลา
# 157               แกงเหลืองใส่ปลา
#
#                           Food and Description English  Energy(kcal)  \
# 0                                       Fish maw soup             83
# 1     Fish maw soup with rice noodles \n(fine thread)             60
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 3                        Rice noodles with beef curry            131
# 4                    Rice noodles with chicken, fried            198
# ..                                                 ...           ...
# 153                         Curry, fermented tiny fish            39
# 154                                  Curry, small fish            74
# 155                              Curry, matsaman, beef           252
# 156                      Kang-som, vegetables and fish            50
# 157                     Yellow curry (sour soup), fish            41
#
#      Protein(g)  Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)
# 0          7.30    5.20                                               1.80
# 1          3.75    0.75                                               9.46
# 2         39.10    1.88                                               8.49
# 3          6.60    7.40                                               9.40
# 4          6.94    8.36                                              23.77
# ..          ...     ...                                                ...
# 153        6.97    0.69                                               1.15
# 154        9.96    2.43                                               3.03
# 155       10.21   23.42                                               0.00
# 156        5.22    2.98                                               0.56
# 157        7.80    0.14                                               1.32
#
# [158 rows x 6 columns]

# %% [markdown]
# ## Cosine Similarity
# **Cosine similarity** หรือ ความคล้ายคลึงโคไซน์ ค่าจะขึ้นอยู่กับมุมที่เวกเตอร์ 2 เวกเตอร์กระทำต่อกัน
# ![Cosine Similarity](image/cosine_similarity.png)
#
# โดยที่ Cosine Similarity จะมีสูตรคำนวณดังนี้
# ### $$D_{Cosine} = cos\theta = \dfrac{u\cdot v}{|u||v|}$$
#
# - $u$ : ข้อมูลชุดที่ 1
# - $v$ : ข้อมูลชุดที่ 2
#
#
# จากสมการนำมาเขียนเป็นอยู่ในรูปผลรวมได้คือ
# ### $$D_{Cosine} = \dfrac{\sum_{i=1}^{n} A_i B_i}{\sqrt{\sum_{i=1}^{n} A_i^2} \sqrt{\sum_{i=1}^{n} B_i^2}}$$

# %%
import math
def cosinSimilarity(lstInput):
    for i in range(158):
        data = np.array([Filter_df['Energy(kcal)'][i],Filter_df['Protein(g)'][i],Filter_df['Fat(g)'][i],Filter_df['Carbohydrate, available\n(carbohydrate, total)(g)'][i]],dtype=float)
        dot = np.dot(lstInput,data)
        magData = np.linalg.norm(data)
        magLstInput = np.linalg.norm(lstInput)
        cosine = dot/(magData*magLstInput)
        degree = float("{0:.3f}".format((math.acos(cosine) * 180/math.pi)))
        
#         print("Cosine =","{0:.6f}".format(cosine),end=' ') 
#         print("Degree =",degree,'°')
        Filter_df.loc[i,'Cosine Similarity'] = "{0:.6f}".format(cosine)
        Filter_df.loc[i,'Degree Cosine Similarity'] = degree

# %% [markdown]
# ### ⌨️ รับข้อมูลจากผู้ใช้

# %%
energy = float(input("Enter Energy(kcal) : "))
protein = float(input("Enter Protein(g) : "))
fat  = float(input("Enter Fat(g) : "))
carbohydrate = float(input("Enter Carbohydrate(g) : "))
lstInput = np.array([energy,protein,fat,carbohydrate])
# printDetail(energy,protein,fat,carbohydrate)
cosinSimilarity(lstInput)
Filter_df
# Out:
# Enter Energy(kcal) : 21
# Enter Protein(g) : 21
# Enter Fat(g) : 21
# Enter Carbohydrate(g) : 21
#         Food and Description Thai  \
# 0                      กระเพาะปลา
# 1            กระเพาะปลา, เส้นหมี่
# 2                  ก๋วยจั๋บน้ำข้น
# 3    ก๋วยเตี๋ยวแขก(ก๋วยเตี๋ยวแกง)
# 4               ก๋วยเตี๋ยวคั่วไก่
# ..                            ...
# 153         แกงน้ำเคย (แกงเคยปลา)
# 154             แกงพริกปลาตัวเล็ก
# 155               แกงมัสมั่นเนื้อ
# 156            แกงส้มผักรวมกับปลา
# 157               แกงเหลืองใส่ปลา
#
#                           Food and Description English  Energy(kcal)  \
# 0                                       Fish maw soup             83
# 1     Fish maw soup with rice noodles \n(fine thread)             60
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 3                        Rice noodles with beef curry            131
# 4                    Rice noodles with chicken, fried            198
# ..                                                 ...           ...
# 153                         Curry, fermented tiny fish            39
# 154                                  Curry, small fish            74
# 155                              Curry, matsaman, beef           252
# 156                      Kang-som, vegetables and fish            50
# 157                     Yellow curry (sour soup), fish            41
#
#      Protein(g)  Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)  \
# 0          7.30    5.20                                               1.80
# 1          3.75    0.75                                               9.46
# 2         39.10    1.88                                               8.49
# 3          6.60    7.40                                               9.40
# 4          6.94    8.36                                              23.77
# ..          ...     ...                                                ...
# 153        6.97    0.69                                               1.15
# 154        9.96    2.43                                               3.03
# 155       10.21   23.42                                               0.00
# 156        5.22    2.98                                               0.56
# 157        7.80    0.14                                               1.32
#
#     Cosine Similarity  Degree Cosine Similarity
# 0            0.582621                    54.365
# 1            0.607610                    52.583
# 2            0.746025                    41.753
# 3            0.586134                    54.117
# 4            0.593513                    53.593
# ..                ...                       ...
# 153          0.603043                    52.912
# 154          0.597981                    53.275
# 155          0.563836                    55.679
# 156          0.583364                    54.313
# 157          0.601823                    52.999
#
# [158 rows x 8 columns]

# %% [markdown]
# ### 〽️ Sort ข้อมูลโดยเรียงลำดับจากมากไปน้อย

# %%
Filter_df.sort_values(['Cosine Similarity'],ascending=0,inplace = True)
Filter_df
# Out:
#                      Food and Description Thai  \
# 2                               ก๋วยจั๋บน้ำข้น
# 12   ก๋วยเตี๋ยวเส้นเล็ก, ลูกชิ้น, เนื้อสด, น้ำ
# 19            ก๋วยเตี๋ยวเส้นหมี่, เนื้อ, น้ำตก
# 54                         ข้าวราดแกงส้มผักรวม
# 55                            ข้าวราดแกงเหลือง
# ..                                         ...
# 149                         แกงไก่ใส่หยวกกล้วย
# 155                            แกงมัสมั่นเนื้อ
# 147                    น้ำพริก, ปลาร้า, ผักลวก
# 150      แกงขี้เหล็ก (ดอกขี้เหล็ก), ใส่ปลาย่าง
# 133                                แกงขี้เหล็ก
#
#                           Food and Description English  Energy(kcal)  \
# 2    Rice noodles, big sheet, soup with meat and to...            67
# 12   Rice noodles, small size with beef ball, beef ...            65
# 19   Rice noodles, fine thread with mix beef and soup             64
# 54   Rice topped with tamarind flavor soup, mixed v...            85
# 55        Rice topped with spicy yellow soup, turmeric           104
# ..                                                 ...           ...
# 149               Curry, chicken and young banana stem           124
# 155                              Curry, matsaman, beef           252
# 147             Namprik-pla-ra with blanched vegetable            88
# 150                   Curry, cassia leaves and flowers           197
# 133                               Curry, cassia leaves           182
#
#      Protein(g)  Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)  \
# 2         39.10    1.88                                               8.49
# 12         5.00    0.60                                               9.88
# 19         5.24    0.69                                               9.15
# 54         2.91    0.23                                              17.77
# 55         3.64    0.55                                              21.19
# ..          ...     ...                                                ...
# 149        6.74   10.00                                               0.00
# 155       10.21   23.42                                               0.00
# 147        3.42    7.99                                               0.00
# 150        4.28   20.00                                               0.00
# 133        2.80   19.02                                               0.00
#
#     Cosine Similarity  Degree Cosine Similarity
# 2            0.746025                    41.753
# 12           0.610259                    52.392
# 19           0.609560                    52.442
# 54           0.609472                    52.449
# 55           0.609130                    52.473
# ..                ...                       ...
# 149          0.564835                    55.609
# 155          0.563836                    55.679
# 147          0.562095                    55.799
# 150          0.558622                    56.039
# 133          0.556847                    56.162
#
# [158 rows x 8 columns]

# %% [markdown]
# ### List ข้อมูลอาหาร 10 อันดับแรก

# %%
Sort_df = Filter_df[['Food and Description Thai','Energy(kcal)','Protein(g)','Fat(g)','Carbohydrate, available\n(carbohydrate, total)(g)']]
Sort_df.head(10)
# Out:
#                      Food and Description Thai  Energy(kcal)  Protein(g)  \
# 2                               ก๋วยจั๋บน้ำข้น            67       39.10
# 12   ก๋วยเตี๋ยวเส้นเล็ก, ลูกชิ้น, เนื้อสด, น้ำ            65        5.00
# 19            ก๋วยเตี๋ยวเส้นหมี่, เนื้อ, น้ำตก            64        5.24
# 54                         ข้าวราดแกงส้มผักรวม            85        2.91
# 55                            ข้าวราดแกงเหลือง           104        3.64
# 100                                   แกงเลียง            30        1.44
# 135                                     แกงบอน            39        1.55
# 49                             ข้าวราดแกงไตปลา           106        3.28
# 1                         กระเพาะปลา, เส้นหมี่            60        3.75
# 144                             ขนมจีนน้ำยาป่า            66        1.96
#
#      Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)
# 2      1.88                                               8.49
# 12     0.60                                               9.88
# 19     0.69                                               9.15
# 54     0.23                                              17.77
# 55     0.55                                              21.19
# 100    0.35                                               5.36
# 135    0.32                                               7.53
# 49     0.73                                              21.66
# 1      0.75                                               9.46
# 144    0.63                                              13.12

# %% [markdown]
# ### Correlation Matrix
#   Correlation หรือ สหสัมพันธ์คือการศึกษาหาความสัมพันธ์ระหว่างตัวแปร 2 ตัวแปรขึ้นไปสามารถเขียนในรูปสมการคือ
#    ### $$r_{xy} = \dfrac{\sum (x_i-\bar x)(y_i-\bar y)}{\sqrt{\sum (x_i-\bar x)^2 \sum (y_i-\bar y)^2}}$$
#
# - $x$ : ข้อมูลชุดที่ 1
# - $y$ : ข้อมูลชุดที่ 2
# - $\bar x $ : ค่าเฉลี่ยของข้อมูลชุดที่ 1
#   $$ \bar x = \dfrac{\sum_{i=1}^{n} x_i}{n}$$
# - $\bar y $ : ค่าเฉลี่ยของข้อมูลชุดที่ 2
#   $$ \bar y = \dfrac{\sum_{i=1}^{n} y_i}{n}$$

# %%
cor = Sort_df.iloc[:10,1:].transpose().corr()
cor
# Out:
#           2         12        19        54        55        100       135  \
# 2    1.000000  0.844130  0.848947  0.803255  0.804916  0.819206  0.810602
# 12   0.844130  1.000000  0.999917  0.996116  0.996617  0.998810  0.997658
# 19   0.848947  0.999917  1.000000  0.994911  0.995494  0.998142  0.996723
# 54   0.803255  0.996116  0.994911  1.000000  0.999974  0.999108  0.999766
# 55   0.804916  0.996617  0.995494  0.999974  1.000000  0.999371  0.999892
# 100  0.819206  0.998810  0.998142  0.999108  0.999371  1.000000  0.999783
# 135  0.810602  0.997658  0.996723  0.999766  0.999892  0.999783  1.000000
# 49   0.801926  0.996310  0.995152  0.999964  0.999986  0.999270  0.999846
# 1    0.833688  0.999815  0.999546  0.997344  0.997792  0.999506  0.998646
# 144  0.802449  0.996647  0.995559  0.999881  0.999954  0.999443  0.999902
#
#           49        1         144
# 2    0.801926  0.833688  0.802449
# 12   0.996310  0.999815  0.996647
# 19   0.995152  0.999546  0.995559
# 54   0.999964  0.997344  0.999881
# 55   0.999986  0.997792  0.999954
# 100  0.999270  0.999506  0.999443
# 135  0.999846  0.998646  0.999902
# 49   1.000000  0.997581  0.999973
# 1    0.997581  1.000000  0.997901
# 144  0.999973  0.997901  1.000000

# %%
fig,ax = plt.subplots(figsize=(20,20))
sns.heatmap(data = cor, cmap='Greens',annot=True,
           annot_kws = {
               'fontsize' : 16,
               'fontweight' : 'bold'
           },fmt='.5g')
Sort_df.head(10)
# Out:
#                      Food and Description Thai  Energy(kcal)  Protein(g)  \
# 2                               ก๋วยจั๋บน้ำข้น            67       39.10
# 12   ก๋วยเตี๋ยวเส้นเล็ก, ลูกชิ้น, เนื้อสด, น้ำ            65        5.00
# 19            ก๋วยเตี๋ยวเส้นหมี่, เนื้อ, น้ำตก            64        5.24
# 54                         ข้าวราดแกงส้มผักรวม            85        2.91
# 55                            ข้าวราดแกงเหลือง           104        3.64
# 100                                   แกงเลียง            30        1.44
# 135                                     แกงบอน            39        1.55
# 49                             ข้าวราดแกงไตปลา           106        3.28
# 1                         กระเพาะปลา, เส้นหมี่            60        3.75
# 144                             ขนมจีนน้ำยาป่า            66        1.96
#
#      Fat(g)  Carbohydrate, available\n(carbohydrate, total)(g)
# 2      1.88                                               8.49
# 12     0.60                                               9.88
# 19     0.69                                               9.15
# 54     0.23                                              17.77
# 55     0.55                                              21.19
# 100    0.35                                               5.36
# 135    0.32                                               7.53
# 49     0.73                                              21.66
# 1      0.75                                               9.46
# 144    0.63                                              13.12
